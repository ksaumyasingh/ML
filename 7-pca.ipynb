# %%
import pandas as pd
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df=pd.read_csv(url,names=['sepal length','sepal width','petal length','petal width','targets'])
df

# %%
#PCA
features=['sepal length','sepal width','petal length','petal width']
x=df.loc[:,features].values
x

# %%
target=['targets']

# %%
y=df.loc[:,['targets']].values
y

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca1=pca.fit_transform(x)
pca1

# %%
X=pd.DataFrame(data=pca1,columns=['feature1','feature2'])
X

# %%
y=pd.DataFrame(data=y,columns=['target'])
y

# %%
df=pd.concat([X,y],axis=1)
df

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(1,1,1)
ax.set_xlabel("feature1", fontsize=15)
ax.set_ylabel("feature2", fontsize=15)
ax.set_title("PCA Visualization", fontsize=15)
targets=["Iris-setosa","Iris-versicolor","Iris-virginica"]
colors=['r','g','b']
for target,color in zip(targets,colors):
  indices=df["target"]==target
  plt.scatter(df.loc[indices,'feature1'],df.loc[indices,'feature2'],c=color,s=50)
  ax.legend(targets)
ax.grid()
